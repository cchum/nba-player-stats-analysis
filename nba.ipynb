# %%
import pandas as pd

# %%
df = pd.read_csv("nba.csv")
df.head(20)
# Out:
#       Rk                   Player   Age Team Pos     G    GS    MP    FG  \
# 0    1.0              Luka Dončić  26.0  LAL  PG  36.0  36.0  36.4  10.4
# 1    2.0  Shai Gilgeous-Alexander  27.0  OKC  PG  44.0  44.0  33.4  11.1
# 2    3.0             Tyrese Maxey  25.0  PHI  PG  42.0  42.0  39.5  10.5
# 3    4.0             Jaylen Brown  29.0  BOS  SF  42.0  42.0  34.5  10.9
# 4    5.0          Anthony Edwards  24.0  MIN  SG  36.0  36.0  35.2  10.2
# 5    6.0             Nikola Jokić  30.0  DEN   C  32.0  32.0  34.6  10.6
# 6    7.0         Donovan Mitchell  29.0  CLE  SG  43.0  43.0  34.2  10.1
# 7    8.0            Kawhi Leonard  34.0  LAC  SF  31.0  31.0  33.5   9.7
# 8    9.0    Giannis Antetokounmpo  31.0  MIL  PF  30.0  30.0  29.2  10.5
# 9   10.0            Jalen Brunson  29.0  NYK  PG  40.0  39.0  34.5  10.0
# 10  11.0          Lauri Markkanen  28.0  UTA  PF  33.0  33.0  36.0   9.5
# 11  12.0            Stephen Curry  37.0  GSW  PG  36.0  36.0  31.7   9.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rk                 529 non-null    float64
#  1   Player             530 non-null    object
#  2   Age                529 non-null    float64
#  3   Team               529 non-null    object
#  4   Pos                529 non-null    object
#  5   G                  529 non-null    float64
#  6   GS                 529 non-null    float64
#  7   MP                 529 non-null    float64
#  8   FG                 529 non-null    float64
#  9   FGA                529 non-null    float64
#  10  FG%                527 non-null    float64
#  11  3P                 529 non-null    float64
#  12  3PA                529 non-null    float64
#  13  3P%                493 non-null    float64
#  14  2P                 529 non-null    float64
# ...
